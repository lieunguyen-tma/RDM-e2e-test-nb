# %%
from datetime import datetime
from getpass import getpass

rdm_url = 'https://develop.rdm.example.com/'
admin_rdm_url = 'https://admin.develop.rdm.example.com/'

idp_name_1 = "None"
idp_username_institutional_admin = 'user_test_admin' # グループA、グループB、グループC、グループDに所属するユーザ
idp_password_institutional_admin = 'password_test_admin'
idp_username_1 = 'user_test01' # グループに所属していないユーザ
idp_password_1 = 'password_test01'
idp_username_2 = 'user_test02' # グループAに所属するユーザ
idp_password_2 = 'password_test02'
idp_username_3 = 'user_test03' # グループBに所属するユーザ
idp_password_3 = 'password_test03'
idp_username_4 = 'user_test04' # グループCに所属するユーザ
idp_password_4 = 'password_test04'
idp_username_5 = 'user_test05' # グループDに所属するユーザ
idp_password_5 = 'password_test05'

display_username_institutional_admin = 'name_user_test_admin'
display_username_1 = 'name_user_test01'
display_username_2 = 'name_user_test02'
display_username_3 = 'name_user_test03'
display_username_4 = 'name_user_test04'
display_username_5 = 'name_user_test05'

group_a = 'GroupA'
group_b = 'GroupB'
group_c = 'GroupC'
group_d = 'GroupD'

group_search = 'Group'
group_note_text = '※本機能はムーンショット目標2'
rdm_project_name = 'TEST-グループ管理連携機能検証-{}'.format(datetime.now().strftime('%Y%m%d'))
target_storage_name = 'NII Storage'
target_storage_id = 'osfstorage'
delete_project = True
run_id = datetime.now().strftime('%Y%m%d-%H%M%S')
default_result_path = f'result/result-{run_id}'
close_on_fail = False
transition_timeout = 60000
skip_failed_test = False
exclude_notebooks = []

# %%
if idp_username_institutional_admin is None:
    idp_username_institutional_admin = input(prompt=f'Username for {idp_name_1}')
if idp_password_institutional_admin is None:
    idp_password_institutional_admin = getpass(prompt=f'Password for {idp_username_institutional_admin}@{idp_name_1}')
(len(idp_username_institutional_admin), len(idp_password_institutional_admin))

# %%
if idp_username_1 is None:
    idp_username_1 = input(prompt=f'Username for {idp_name_1}')
if idp_password_1 is None:
    idp_password_1 = getpass(prompt=f'Password for {idp_username_1}@{idp_name_1}')
(len(idp_username_1), len(idp_password_1))

if idp_username_2 is None:
    idp_username_2 = input(prompt=f'Username for {idp_name_1}')
if idp_password_2 is None:
    idp_password_2 = getpass(prompt=f'Password for {idp_username_2}@{idp_name_1}')
(len(idp_username_2), len(idp_password_2))

if idp_username_3 is None:
    idp_username_3 = input(prompt=f'Username for {idp_name_1}')
if idp_password_3 is None:
    idp_password_3 = getpass(prompt=f'Password for {idp_username_3}@{idp_name_1}')
(len(idp_username_3), len(idp_password_3))

if idp_username_4 is None:
    idp_username_4 = input(prompt=f'Username for {idp_name_1}')
if idp_password_4 is None:
    idp_password_4 = getpass(prompt=f'Password for {idp_username_4}@{idp_name_1}')
(len(idp_username_4), len(idp_password_4))

if idp_username_5 is None:
    idp_username_5 = input(prompt=f'Username for {idp_name_1}')
if idp_password_5 is None:
    idp_password_5 = getpass(prompt=f'Password for {idp_username_5}@{idp_name_1}')
(len(idp_username_5), len(idp_password_5))

# %%
import tempfile

work_dir = tempfile.mkdtemp()
if default_result_path is None:
    default_result_path = work_dir
work_dir

# %% [markdown]
# # GakuNinRDM 総合テスト [グループ管理連携機能]
#
# - サブシステム名: グループ管理連携機能
# - ページ/アドオン: グループ
# - 機能分類: グループ管理連携機能
# - シナリオ名: *
# - 用意するテストデータ: URL一覧、アカウント(既存ユーザー1: GRDM)

# %%
from datetime import datetime
import os
from scripts.papermillHelpers import gen_run_notebook

def make_result_dir(base_path):
    result_dir = os.path.join(base_path, 'notebooks')
    os.makedirs(result_dir, exist_ok=True)
    return result_dir

result_dir = make_result_dir(default_result_path)

run_notebook = gen_run_notebook(
    result_dir,
    transition_timeout,
    dict(
        rdm_url=rdm_url,
        idp_name_1=idp_name_1,
        idp_username_institutional_admin=idp_username_institutional_admin,
        idp_password_institutional_admin=idp_password_institutional_admin,
    ),
    skip_failed_test,
)

result_notebooks = []
result_dir

# %% [markdown]
# ## 「アドオン利用制御」テストの実施
#
# テスト「テスト手順-グループ-アドオン利用制御」を実施する。

# %%
result_notebooks.append(run_notebook('テスト手順-グループ-アドオン利用制御.ipynb',
    dict(
        admin_rdm_url=admin_rdm_url
    )
))
result_notebooks[-1]

# %% [markdown]
# ## 「プロジェクトに対するグループ機能①」テストの実施
#
# テスト「テスト手順-プロジェクトに対するグループ機能」を実施する。

# %%
result_notebooks.append(run_notebook(
    'テスト手順-グループ-プロジェクトに対するグループ機能①.ipynb',
    dict(
        display_username_1=display_username_1,
        display_username_2=display_username_2,
        display_username_3=display_username_3,
        group_a=group_a,
        group_b=group_b,
        group_c=group_c,
        group_d=group_d,
        group_search=group_search,
        rdm_project_name=rdm_project_name,
        group_note_text=group_note_text,
    )
))
result_notebooks[-1]

# %% [markdown]
# ## 「グループ権限によるプロジェクトに対する操作」テストの実施
#
# テスト「テスト手順-グループ権限によるプロジェクトに対する操作」を実施する。

# %%
result_notebooks.append(run_notebook(
    'テスト手順-グループ-グループ権限によるプロジェクトに対する操作.ipynb',
    dict(
        idp_username_2=idp_username_2,
        idp_password_2=idp_password_2,
        idp_username_3=idp_username_3,
        idp_password_3=idp_password_3,
        idp_username_4=idp_username_4,
        idp_password_4=idp_password_4,
        idp_username_5=idp_username_5,
        idp_password_5=idp_password_5,
        group_a=group_a,
        group_b=group_b,
        group_c=group_c,
        group_d=group_d,
        rdm_project_name=rdm_project_name,
        group_note_text=group_note_text,
    )
))
result_notebooks[-1]

# %% [markdown]
# ## 「グループ権限によるコンポーネントに対する操作」テストの実施
#
# テスト「テスト手順-グループ権限によるコンポーネントに対する操作」を実施する。

# %%
result_notebooks.append(run_notebook(
    'テスト手順-グループ-グループ権限によるコンポーネントに対する操作.ipynb',
    dict(
        idp_username_2=idp_username_2,
        idp_password_2=idp_password_2,
        idp_username_4=idp_username_4,
        idp_password_4=idp_password_4,
        display_username_institutional_admin=display_username_institutional_admin,
        display_username_1=display_username_1,
        display_username_2=display_username_2,
        display_username_3=display_username_3,
        group_a=group_a,
        group_b=group_b,
        group_c=group_c,
        group_d=group_d,
        rdm_project_name=rdm_project_name,
        group_note_text=group_note_text,
    )
))
result_notebooks[-1]

# %% [markdown]
# ## 「プロジェクトに対するグループ機能②」テストの実施
#
# テスト「テスト手順-プロジェクトに対するグループ機能」を実施する。

# %%
result_notebooks.append(run_notebook(
    'テスト手順-グループ-プロジェクトに対するグループ機能②.ipynb',
    dict(
        admin_rdm_url=admin_rdm_url,
        idp_username_1=idp_username_1,
        idp_password_1=idp_password_1,
        display_username_institutional_admin=display_username_institutional_admin,
        display_username_1=display_username_1,
        display_username_2=display_username_2,
        display_username_3=display_username_3,
        display_username_4=display_username_4,
        display_username_5=display_username_5,
        group_a=group_a,
        group_b=group_b,
        group_c=group_c,
        group_d=group_d,
        rdm_project_name=rdm_project_name,
        group_note_text=group_note_text,
    )
))
result_notebooks[-1]
